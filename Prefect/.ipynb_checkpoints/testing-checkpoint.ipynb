# %%
import pandas as pd
import path as Path

# %%
df = pd.read_csv("https://github.com/vaastav/Fantasy-Premier-League/raw/master/data/2022-23/players_raw.csv")

# %%
df.head()
# Out:
#    assists  bonus  bps chance_of_playing_next_round  \
# 0        5      7  409                         None
# 1        0      0   27                            0
# 2        0      0   23                         None
# 3        0      6  336                          100
# 4        7     21  558                          100
#
#   chance_of_playing_this_round  clean_sheets  clean_sheets_per_90    code  \
# 0                         None            10                 0.43   84450
# 1                            0             0                 0.00  153256
# 2                         None             0                 0.00  156074
# 3                          100             9                 0.48  167199
# 4                          100            10                 0.42  184029
#
#   corners_and_indirect_freekicks_order  corners_and_indirect_freekicks_text  \
# 0                                 None                                  NaN
# ...

# %%
final_table_columns = ["first_name","second_name","goals_scored","assists","total_points,minutes","goals_conceded","creativity","influence","threat","bonus","bps","ict_index","clean_sheets","red_cards","yellow_cards","selected_by_percent","now_cost","element_type","team_code"]

df.drop(columns=[col for col in df if col not in final_table_columns], inplace=True)

# %%
df.head()
# Out:
#    assists  bonus  bps  clean_sheets  creativity  element_type first_name  \
# 0        5      7  409            10       524.6             3     Granit
# 1        0      0   27             0         5.4             3    Mohamed
# 2        0      0   23             0         0.1             2        Rob
# 3        0      6  336             9       330.6             3     Thomas
# 4        7     21  558            10       867.5             3     Martin
#
#    goals_conceded  goals_scored  ict_index  influence  now_cost  red_cards  \
# 0              23             3      131.7      449.2        49          0
# 1               2             0        1.1        4.6        41          0
# 2               0             0        0.3        3.4        42          0
# 3              13             3       94.6      402.2        47          0
# 4              24             9      220.7      647.2        70          0
#
#   second_name  selected_by_percent  team_code  threat  yellow_cards
# ...

# %%
yearOne = 16
df["KO_Year"] = f"20{yearOne}-"

# %%
df.head()
# Out:
#    assists  bonus  bps  clean_sheets  creativity  element_type first_name  \
# 0        5      7  409            10       524.6             3     Granit
# 1        0      0   27             0         5.4             3    Mohamed
# 2        0      0   23             0         0.1             2        Rob
# 3        0      6  336             9       330.6             3     Thomas
# 4        7     21  558            10       867.5             3     Martin
#
#    goals_conceded  goals_scored  ict_index  influence  now_cost  red_cards  \
# 0              23             3      131.7      449.2        49          0
# 1               2             0        1.1        4.6        41          0
# 2               0             0        0.3        3.4        42          0
# 3              13             3       94.6      402.2        47          0
# 4              24             9      220.7      647.2        70          0
#
# ...

# %%
df["KO_Year"] = pd.to_datetime(df["KO_Year"])
df.head()
# Out:
#    assists  bonus  bps  clean_sheets  creativity  element_type first_name  \
# 0        5      7  409            10       524.6             3     Granit
# 1        0      0   27             0         5.4             3    Mohamed
# 2        0      0   23             0         0.1             2        Rob
# 3        0      6  336             9       330.6             3     Thomas
# 4        7     21  558            10       867.5             3     Martin
#
#    goals_conceded  goals_scored  ict_index  influence  now_cost  red_cards  \
# 0              23             3      131.7      449.2        49          0
# 1               2             0        1.1        4.6        41          0
# 2               0             0        0.3        3.4        42          0
# 3              13             3       94.6      402.2        47          0
# 4              24             9      220.7      647.2        70          0
#
# ...
